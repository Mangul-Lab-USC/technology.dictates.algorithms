# %%
import pandas as pd
data=pd.read_csv('../data/Table1_update.csv')
data_year = data_year = data.loc[:,['Year_of_publication', 'Aligner', 'Application', 'Indexing', 
                                    'Global_Positioning', 'Pairwise_alignment', 'DP_pairwise',
                                    'fix_length_seed', 'variable_length_seed', 'spaced_seed',
                                    'chain_of_seeds','Wrapper','wrapper_of_tool']]
data_year.loc[data_year.loc[:,'Indexing'] == 'hashing', 'Index'] = 'Hashing'
data_year.loc[data_year.loc[:,'Indexing'] == 'BWT-FM', 'Index'] = 'BWT-FM'
data_year.loc[data_year.loc[:,'Indexing'] == 'suffix array', 'Index'] = 'Other Suffix'
data_year.loc[data_year.loc[:,'Indexing'] == 'BWT-ST', 'Index'] = 'Other Suffix'
data_year.loc[data_year.loc[:,'Indexing'] == 'suffix tree', 'Index'] = 'Other Suffix'

data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'SW', 'Pairwise'] = 'Smith-Waterman'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'HD', 'Pairwise'] = 'Hamming Distance'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'NW', 'Pairwise'] = 'Needleman-Wunsch'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Non-DP Heuristic', 'Pairwise'] = 'Non-DP Heuristic'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'SW & NW', 'Pairwise'] = 'Multiple Methods'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'SW & Semi-Global', 'Pairwise'] = 'Multiple Methods'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Rabin-Karp Algorithm', 'Pairwise'] = 'Other DP'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Landau-Vishkin', 'Pairwise'] = 'Other DP'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Sparse DP', 'Pairwise'] = 'Other DP'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Banded Myers Bit Vector', 'Pairwise'] = 'Other DP'
data_year.loc[data_year.loc[:,'Pairwise_alignment'] == 'Semi-Global', 'Pairwise'] = 'Other DP'

data_year.loc[data_year.loc[:,'DP_pairwise'] == 'Y', 'Dynamic Programming'] = 'Yes'
data_year.loc[data_year.loc[:,'DP_pairwise'] == 'N', 'Dynamic Programming'] = 'No'

data_year.loc[data_year.loc[:,'fix_length_seed'] == 'Y', 'Fixed Length Seed'] = 'Yes'
data_year.loc[data_year.loc[:,'fix_length_seed'] == 'N', 'Fixed Length Seed'] = 'No'

data_year.loc[data_year.loc[:,'variable_length_seed'] == 'Y', 'Variable Length Seed'] = 'Yes'
data_year.loc[data_year.loc[:,'variable_length_seed'] == 'N', 'Variable Length Seed'] = 'No'

data_year.loc[data_year.loc[:,'chain_of_seeds'] == 'Y', 'Chain of Seeds'] = 'Yes'
data_year.loc[data_year.loc[:,'chain_of_seeds'] == 'N', 'Chain of Seeds'] = 'No'

data_year.loc[data_year.loc[:,'spaced_seed'] == 'Y', 'Spaced Seed'] = 'Yes'
data_year.loc[data_year.loc[:,'spaced_seed'] == 'N', 'Spaced Seed'] = 'No'

# data_year.astype({'Year_of_publication': 'int'})

data_year.head()
# Out:
#    Year_of_publication      Aligner  Application      Indexing  \
# 0                 2019       deSALT      RNA-seq       hashing
# 1                 2018     lordFAST          DNA       hashing
# 2                 2018  Magic-BLAST  DNA/RNA-Seq       hashing
# 3                 2018     minimap2  DNA/RNA-Seq       hashing
# 4                 2018      MUMmer4          DNA  suffix array
#
#   Global_Positioning Pairwise_alignment DP_pairwise fix_length_seed  \
# 0               seed                 SW           Y               Y
# 1               seed                 NW           Y               Y
# 2               seed                 SW           Y               Y
# 3               seed                 NW           Y               Y
# 4                NaN                 SW           Y               Y
#
#   variable_length_seed spaced_seed chain_of_seeds Wrapper wrapper_of_tool  \
# 0                    N           N              Y       N             NaN
# 1                    N           N              Y       N             NaN
# 2                    N           N              N       N             NaN
# 3                    N           N              Y       N             NaN
# 4                    N           N              Y       Y         essaMEM
#
#           Index          Pairwise Dynamic Programming Fixed Length Seed  \
# 0       Hashing    Smith-Waterman                 Yes               Yes
# 1       Hashing  Needleman-Wunsch                 Yes               Yes
# 2       Hashing    Smith-Waterman                 Yes               Yes
# 3       Hashing  Needleman-Wunsch                 Yes               Yes
# 4  Other Suffix    Smith-Waterman                 Yes               Yes
#
#   Variable Length Seed Chain of Seeds Spaced Seed
# 0                   No            Yes          No
# 1                   No            Yes          No
# 2                   No             No          No
# 3                   No            Yes          No
# 4                   No            Yes          No

# %%
from matplotlib import cm

clrs = ['cornflowerblue', 'darkorange', 'limegreen', 'crimson', 'plum', 'peru', 'aquamarine', 
        'pink', 'darkgrey', 'yellowgreen', 'lightcoral', 'gold']

# %%
data_year[(data_year.Application == 'RNA-Seq') | (data_year.Application == 'DNA/RNA-Seq')]
# Out:
#     Year_of_publication       Aligner  Application      Indexing  \
# 2                  2018   Magic-BLAST  DNA/RNA-Seq       hashing
# 3                  2018      minimap2  DNA/RNA-Seq       hashing
# 6                  2017          DART      RNA-Seq        BWT-FM
# 12                 2015  ContextMap 2      RNA-Seq        BWT-FM
# 13                 2015         HISAT      RNA-Seq        BWT-FM
# 19                 2014        JAGuaR      RNA-Seq        BWT-FM
# 24                 2013          CRAC      RNA-Seq        BWT-FM
# 28                 2013          STAR      RNA-Seq  suffix array
# 29                 2013       Subread      RNA-Seq       hashing
# 30                 2013       TopHat2      RNA-Seq        BWT-FM
# 36                 2012           OSA      RNA-Seq       hashing
# 37                 2012       Passion      RNA-Seq       hashing
# 48                 2011    SOAPSplice      RNA-Seq        BWT-FM
# 55                 2010     MapSplice      RNA-Seq        BWT-FM
# 56                 2010   MicroRazerS      RNA-Seq       hashing
# 60                 2010     SpliceMap      RNA-Seq       hashing
# 61                 2010    Supersplat      RNA-Seq       hashing
# 80                 2009        TopHat      RNA-Seq        BWT-FM
# 83                 2008        QPALMA      RNA-Seq  suffix array
#
#    Global_Positioning Pairwise_alignment DP_pairwise fix_length_seed  \
# 2                seed                 SW           Y               Y
# 3                seed                 NW           Y               Y
# 6     Backward Search                 NW           Y               N
# 12    Backward Search            SW & NW           Y               Y
# 13    Backward Search   Non-DP Heuristic           N               Y
# 19    Backward Search                 SW           Y               Y
# 24               seed   Non-DP Heuristic           N               Y
# 28               seed                 SW           Y               N
# 29               seed                 SW           Y               Y
# 30               seed            SW & NW           Y               Y
# 36     chain of seeds                NaN           N               Y
# 37               seed                 SW           Y               Y
# 48               seed   Non-DP Heuristic           N               Y
# 55    Backward Search                 HD           N               Y
# 56              seed                  HD           N               Y
# 60               seed                 HD           N               Y
# 61               seed                NaN           N               N
# 80    Backward Search                 HD           N               Y
# 83               seed                 SW           Y               Y
#
#    variable_length_seed spaced_seed chain_of_seeds Wrapper  \
# 2                     N           N              N       N
# 3                     N           N              Y       N
# 6                     Y           N              Y       N
# 12                    N           N              Y       Y
# 13                    N           N              N       N
# 19                    N           N              N       Y
# 24                    N           N              N       N
# 28                    Y           N              Y       N
# 29                    N           Y              Y       N
# 30                    N           N              Y       Y
# 36                    N           N              N       N
# 37                    N           N              Y       Y
# 48                    N           N              N       N
# 55                    N           N              N       Y
# 56                    N           N              Y       N
# 60                    N           N              N       Y
# 61                    Y           N              N       N
# 80                    N           N              N       Y
# 83                    N           N              Y       Y
#
#                  wrapper_of_tool         Index          Pairwise  \
# 2                            NaN       Hashing    Smith-Waterman
# 3                            NaN       Hashing  Needleman-Wunsch
# 6                            NaN        BWT-FM  Needleman-Wunsch
# 12  bowtie, bowtie 2, or bwa, ..        BWT-FM  Multiple Methods
# 13                           NaN        BWT-FM  Non-DP Heuristic
# 19                 BWA (wrapper)        BWT-FM    Smith-Waterman
# 24                           NaN        BWT-FM  Non-DP Heuristic
# 28                           NaN  Other Suffix    Smith-Waterman
# 29                           NaN       Hashing    Smith-Waterman
# 30                       Bowtie2        BWT-FM  Multiple Methods
# 36                           NaN       Hashing               NaN
# 37               SMALT (wrapper)       Hashing    Smith-Waterman
# 48                           NaN        BWT-FM  Non-DP Heuristic
# 55              Bowtie (wrapper)        BWT-FM  Hamming Distance
# 56            RazerS (extention)       Hashing  Hamming Distance
# 60                        Bowtie       Hashing  Hamming Distance
# 61                           NaN       Hashing               NaN
# 80                       Bowtie         BWT-FM  Hamming Distance
# 83                        vmatch  Other Suffix    Smith-Waterman
#
#    Dynamic Programming Fixed Length Seed Variable Length Seed Chain of Seeds  \
# 2                  Yes               Yes                   No             No
# 3                  Yes               Yes                   No            Yes
# 6                  Yes                No                  Yes            Yes
# 12                 Yes               Yes                   No            Yes
# 13                  No               Yes                   No             No
# 19                 Yes               Yes                   No             No
# 24                  No               Yes                   No             No
# 28                 Yes                No                  Yes            Yes
# 29                 Yes               Yes                   No            Yes
# 30                 Yes               Yes                   No            Yes
# 36                  No               Yes                   No             No
# 37                 Yes               Yes                   No            Yes
# 48                  No               Yes                   No             No
# 55                  No               Yes                   No             No
# 56                  No               Yes                   No            Yes
# 60                  No               Yes                   No             No
# 61                  No                No                  Yes             No
# 80                  No               Yes                   No             No
# 83                 Yes               Yes                   No            Yes
#
#    Spaced Seed
# 2           No
# 3           No
# 6           No
# 12          No
# 13          No
# 19          No
# 24          No
# 28          No
# 29         Yes
# 30          No
# 36          No
# 37          No
# 48          No
# 55          No
# 56          No
# 60          No
# 61          No
# 80          No
# 83          No

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

sns.set_style('white')
sns.set_context('talk')

tmpclrs = ['darkorange', 'cornflowerblue', 'limegreen']

plt.figure(figsize=(11,4))
idx_group = data_year[(data_year.Application == 'RNA-Seq') | (data_year.Application == 'DNA/RNA-Seq')].groupby('Index').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=tmpclrs[::-1])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
#plt.show()
plt.tight_layout()

plt.savefig('../figures/rna_pie.png')

# %%
by_year = data_year[(data_year.Application == 'RNA-Seq') | (data_year.Application == 'DNA/RNA-Seq')].groupby(['Year_of_publication','Index']).count()
by_year = by_year.xs('Aligner', axis=1)
by_year = by_year.unstack(level = -1, fill_value=0)
by_year = by_year.cumsum()
x = by_year.index
by_year

plt.stackplot(x, by_year.loc[:,'BWT-FM'], by_year.loc[:,'Hashing'], by_year.loc[:,'Other Suffix'], 
              labels=['BWT-FM','Hashing','Other Suffix'], colors=tmpclrs)
#plt.legend(loc='center left', bbox_to_anchor=(1, .5))
plt.xticks(range(min(x), max(x)+1, 2))
plt.title('RNA-Seq Tools over the Years')
#plt.show()

plt.tight_layout()
plt.savefig('../figures/rna_by_year.png')

# %%
wrappers = data_year[(data_year.Wrapper == 'N') & ((data_year.Application == 'RNA-Seq') | (data_year.Application == 'DNA/RNA-Seq'))]

wrappers
# Out:
#     Year_of_publication      Aligner  Application      Indexing  \
# 2                  2018  Magic-BLAST  DNA/RNA-Seq       hashing
# 3                  2018     minimap2  DNA/RNA-Seq       hashing
# 6                  2017         DART      RNA-Seq        BWT-FM
# 13                 2015        HISAT      RNA-Seq        BWT-FM
# 24                 2013         CRAC      RNA-Seq        BWT-FM
# 28                 2013         STAR      RNA-Seq  suffix array
# 29                 2013      Subread      RNA-Seq       hashing
# 36                 2012          OSA      RNA-Seq       hashing
# 48                 2011   SOAPSplice      RNA-Seq        BWT-FM
# 56                 2010  MicroRazerS      RNA-Seq       hashing
# 61                 2010   Supersplat      RNA-Seq       hashing
#
#    Global_Positioning Pairwise_alignment DP_pairwise fix_length_seed  \
# 2                seed                 SW           Y               Y
# 3                seed                 NW           Y               Y
# 6     Backward Search                 NW           Y               N
# 13    Backward Search   Non-DP Heuristic           N               Y
# 24               seed   Non-DP Heuristic           N               Y
# 28               seed                 SW           Y               N
# 29               seed                 SW           Y               Y
# 36     chain of seeds                NaN           N               Y
# 48               seed   Non-DP Heuristic           N               Y
# 56              seed                  HD           N               Y
# 61               seed                NaN           N               N
#
#    variable_length_seed spaced_seed chain_of_seeds Wrapper  \
# 2                     N           N              N       N
# 3                     N           N              Y       N
# 6                     Y           N              Y       N
# 13                    N           N              N       N
# 24                    N           N              N       N
# 28                    Y           N              Y       N
# 29                    N           Y              Y       N
# 36                    N           N              N       N
# 48                    N           N              N       N
# 56                    N           N              Y       N
# 61                    Y           N              N       N
#
#        wrapper_of_tool         Index          Pairwise Dynamic Programming  \
# 2                  NaN       Hashing    Smith-Waterman                 Yes
# 3                  NaN       Hashing  Needleman-Wunsch                 Yes
# 6                  NaN        BWT-FM  Needleman-Wunsch                 Yes
# 13                 NaN        BWT-FM  Non-DP Heuristic                  No
# 24                 NaN        BWT-FM  Non-DP Heuristic                  No
# 28                 NaN  Other Suffix    Smith-Waterman                 Yes
# 29                 NaN       Hashing    Smith-Waterman                 Yes
# 36                 NaN       Hashing               NaN                  No
# 48                 NaN        BWT-FM  Non-DP Heuristic                  No
# 56  RazerS (extention)       Hashing  Hamming Distance                  No
# 61                 NaN       Hashing               NaN                  No
#
#    Fixed Length Seed Variable Length Seed Chain of Seeds Spaced Seed
# 2                Yes                   No             No          No
# 3                Yes                   No            Yes          No
# 6                 No                  Yes            Yes          No
# 13               Yes                   No             No          No
# 24               Yes                   No             No          No
# 28                No                  Yes            Yes          No
# 29               Yes                   No            Yes         Yes
# 36               Yes                   No             No          No
# 48               Yes                   No             No          No
# 56               Yes                   No            Yes          No
# 61                No                  Yes             No          No

# %%
plt.figure(figsize=(11,4))
idx_group = wrappers.groupby('Index').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=clrs[2::-1])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
#plt.show()
plt.tight_layout()
plt.savefig('../figures/rna_nonwrappers.png')

# %%
by_year = wrappers.groupby(['Year_of_publication','Index']).count()
by_year = by_year.xs('Aligner', axis=1)
by_year = by_year.unstack(level = -1, fill_value=0)
by_year = by_year.cumsum()
x = by_year.index
by_year

plt.stackplot(x, by_year.loc[:,'Hashing'], by_year.loc[:,'BWT-FM'], by_year.loc[:,'Other Suffix'], 
              labels=['Hashing','BWT-FM','Other Suffix'], colors=clrs)
#plt.legend(loc='center left', bbox_to_anchor=(1, .5))
plt.xticks(range(min(x), max(x)+1, 2))
plt.title('RNA-Seq Non-Wrappers over the Years')
#plt.show()
plt.tight_layout()
plt.savefig('../figures/rna_nonwrappers_by_year.png')

# %%
plt.figure(figsize=(11,4))
idx_group = data_year[(data_year.Application == 'RNA-Seq') | (data_year.Application == 'DNA/RNA-Seq')].groupby('Wrapper').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=clrs[:2])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
#labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
leg = plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
leg.get_texts()[0].set_text('{0} - {1} ({2:2.2f} %)'.format("Yes", idx_group.Aligner[0], pct[0]))
leg.get_texts()[1].set_text('{0} - {1} ({2:2.2f} %)'.format("No", idx_group.Aligner[1], pct[1]))
plt.title("RNA-Seq Tools Classified as Wrappers")
#plt.show()
plt.tight_layout()
plt.savefig('../figures/rna_wrappers.png')

# %%
bs_tools = data_year[(data_year.Application == 'BS-Seq')]
bs_tools
# Out:
#     Year_of_publication     Aligner Application Indexing Global_Positioning  \
# 22                 2013  BS-Seeker2      BS-Seq   BWT-FM    Backward Search
# 34                 2012     BRAT-BW      BS-Seq   BWT-FM    Backward Search
# 43                 2011     Bismark      BS-Seq   BWT-FM    Backward Search
# 51                 2010   BS-Seeker      BS-Seq   BWT-FM    Backward Search
# 65                 2009        BRAT      BS-Seq  hashing               seed
# 66                 2009       BSMAP      BS-Seq  hashing               seed
#
#    Pairwise_alignment DP_pairwise fix_length_seed variable_length_seed  \
# 22            SW & NW           Y               Y                    N
# 34                 HD           N               N                    Y
# 43                 HD           N               Y                    N
# 51                 HD           N               Y                    N
# 65                 HD           N               Y                    N
# 66                 HD           N               Y                    N
#
#    spaced_seed chain_of_seeds Wrapper    wrapper_of_tool    Index  \
# 22           N              Y       Y  Bowtie2 (wrapper)   BWT-FM
# 34           N              N       N                NaN   BWT-FM
# 43           N              N       Y             bowtie   BWT-FM
# 51           N              N       Y   Bowtie (wrapper)   BWT-FM
# 65           N              N       N                NaN  Hashing
# 66           N              N       N                NaN  Hashing
#
#             Pairwise Dynamic Programming Fixed Length Seed  \
# 22  Multiple Methods                 Yes               Yes
# 34  Hamming Distance                  No                No
# 43  Hamming Distance                  No               Yes
# 51  Hamming Distance                  No               Yes
# 65  Hamming Distance                  No               Yes
# 66  Hamming Distance                  No               Yes
#
#    Variable Length Seed Chain of Seeds Spaced Seed
# 22                   No            Yes          No
# 34                  Yes             No          No
# 43                   No             No          No
# 51                   No             No          No
# 65                   No             No          No
# 66                   No             No          No

# %%
plt.figure(figsize=(11,4))
idx_group = bs_tools.groupby('Index').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=tmpclrs[1::-1])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
#plt.show()
plt.tight_layout()
plt.savefig('../figures/bs_pie.png')

# %%
by_year = bs_tools.groupby(['Year_of_publication','Index']).count()
by_year = by_year.xs('Aligner', axis=1)
by_year = by_year.unstack(level = -1, fill_value=0)
by_year = by_year.cumsum()
x = by_year.index
by_year

plt.stackplot(x, by_year.loc[:,'BWT-FM'], by_year.loc[:,'Hashing'], 
              labels=['BWT-FM','Hashing'], colors=tmpclrs)
#plt.legend(loc='center left', bbox_to_anchor=(1, .5))
plt.xticks(range(min(x), max(x)+1, 1))
plt.title('BS-Seq Tools over the Years')
#plt.show()
plt.tight_layout()
plt.savefig('../figures/bs_by_year.png')

# %%
plt.figure(figsize=(11,4))
idx_group = bs_tools.groupby('Wrapper').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=clrs[1::-1])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
leg = plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
leg.get_texts()[0].set_text('{0} - {1} ({2:2.2f} %)'.format("Yes", idx_group.Aligner[0], pct[0]))
leg.get_texts()[1].set_text('{0} - {1} ({2:2.2f} %)'.format("No", idx_group.Aligner[1], pct[1]))
plt.title("BS-Seq Tools Classified as Wrappers")
#plt.show()
plt.tight_layout()
plt.savefig('../figures/bs_wrappers.png')

# %%
plt.figure(figsize=(11,4))
idx_group = bs_tools[(bs_tools.Wrapper == 'N')].groupby('Index').count().sort_values('Aligner', ascending=True)
patches, texts = plt.pie(idx_group.Aligner, colors=tmpclrs[:2:1])
pct = 100.*idx_group.Aligner/idx_group.Aligner.sum()
labels = ['{0} - {1} ({2:2.2f} %)'.format(i,j,k) for i,j,k in zip(idx_group.index, idx_group.Aligner, pct)]
plt.legend(patches, labels, loc='center left', bbox_to_anchor=(.9, .5))
#plt.show()
plt.tight_layout()
plt.savefig('../figures/bs_nonwrappers.png')

# %%
by_year = bs_tools[(bs_tools.Wrapper == 'N')].groupby(['Year_of_publication','Index']).count()
by_year = by_year.xs('Aligner', axis=1)
by_year = by_year.unstack(level = -1, fill_value=0)
by_year = by_year.cumsum()
x = by_year.index
by_year

plt.stackplot(x, by_year.loc[:,'Hashing'], by_year.loc[:,'BWT-FM'], 
              labels=['Hashing','BWT-FM'], colors=clrs)
#plt.legend(loc='center left', bbox_to_anchor=(1, .5))
plt.xticks(range(min(x), max(x)+1, 1))
plt.title('BS-Seq Tools over the Years')
#plt.show()
plt.tight_layout()
plt.savefig('../figures/bs_nonwrappers_by_year.png')
