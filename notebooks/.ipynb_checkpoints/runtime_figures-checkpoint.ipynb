# %%
import pandas as pd
data=pd.read_csv('../data/Table1_new.csv')
data['age']=2019-data['Year_of_publication']+1
data['citation_per_year']=data['Number_of_Citations']/data['age']
data.head(3)
# Out:
#    Unnamed: 0  Year_of_publication  Aligner  \
# 0        43.0                 2011  Bismark
# 1        16.0                 2009     BRAT
# 2        54.0                 2012  BRAT-BW
#
#                                                  URL              Citation  \
# 0  https://www.bioinformatics.babraham.ac.uk/proj...  Krueger et al. ‎2011
# 1                    http://compbio.cs.ucr.edu/brat/    Harris et al. 2009
# 2                    http://compbio.cs.ucr.edu/brat/    Harris et al. 2012
#
#    read_length max_read_length_tested  \
# 0  Ultra-short                     50
# 1  Ultra-short                     26
# 2  Ultra-short                     62
#
#                                                Title  Number_of_Citations  \
# 0  Bismark: a flexible aligner and methylation ca...                 1550
# 1        BRAT: bisulfite-treated reads analysis tool                   64
# 2  BRAT-BW: efficient and accurate mapping of bis...                   70
#
#   Indexing  ... fix length seed Variable length seed (hybrid seeding)  \
# 0   BWT-FM  ...               Y                                     N
# 1  Hashing  ...               Y                                     N
# 2   BWT-FM  ...               N                                     Y
#
#   spaced seed chain_of_seeds Application       email - first author  \
# 0           N              N      BS-Seq  felix.krueger@bbsrc.ac.uk
# 1           N              N      BS-Seq          elenah@cs.ucr.edu
# 2           N              N      BS-Seq     elenayharris@gmail.com
#
#        email - last author Verified age citation_per_year
# 0                      NaN      NaN   9        172.222222
# 1  stefano.lonardi@ucr.edu      NaN  11          5.818182
# 2  stefano.lonardi@ucr.edu      NaN   8          8.750000
#
# [3 rows x 26 columns]

# %%
rt = pd.read_csv('../data/compare.tools.runtime.hours.csv')
idx_rt = pd.read_csv('../data/compare.tools.index.csv')
mem = pd.read_csv('../data/compare.tools.memory.csv')

# %%
data_year = data.loc[:,['Year_of_publication', 'Aligner', 'Application', 'Indexing', 'Global_Positioning', 'Pairwise_alignment_2']]
data_year.loc[:,'aligner_lower'] = data_year['Aligner'].str.lower()
rt.loc[:,'tools_lower'] = rt['Tools'].str.lower()
rtyear = pd.merge(rt, data_year, left_on='tools_lower', right_on='aligner_lower', how='inner')
rtyear.loc[:,'average_runtime'] = rtyear.iloc[:,1:11].mean(axis=1)
rtyear_summ = rtyear.loc[:,['Tools', 'Year_of_publication', 'average_runtime', 'Application', 'Indexing', 'Global_Positioning', 'Pairwise_alignment_2']]
rtyear_summ.sort_values(by=['Year_of_publication'], inplace=True)
for i in range(0,16):
    rtyear.loc[i,'year_split'] = 'Before 2012' if rtyear.loc[i,'Year_of_publication'] < 2012 else '2012 and later'
rtyear_new = pd.melt(rtyear, id_vars = ['Tools', 'year_split', 'Application', 'Indexing', 'Global_Positioning', 'Pairwise_alignment_2'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'runtime')
rtyear_summ
# Out:
#          Tools  Year_of_publication  average_runtime  Application  \
# 9         rmap                 2008        12.950420          DNA
# 1       Bowtie                 2009         6.102213          DNA
# 2          BWA                 2009         6.239311          DNA
# 4        gsnap                 2010        20.924469          DNA
# 10       smalt                 2010        32.163790          DNA
# 6         last                 2011        20.221401          DNA
# 11        snap                 2011         1.165595          DNA
# 12  soapsplice                 2011        19.710631      RNA-Seq
# 0      Bowtie2                 2012         4.973138          DNA
# 13        STAR                 2013         1.044570      RNA-Seq
# 14     subread                 2013         1.245445      RNA-Seq
# 15     tophat2                 2013        27.529830      RNA-Seq
# 5       hisat2                 2015         1.158713          DNA
# 3         ERNE                 2016         8.281991          DNA
# 7     lordfast                 2018         0.208568          DNA
# 8     minimap2                 2018         1.866426  DNA/RNA-Seq
#
#         Indexing Global_Positioning Pairwise_alignment_2
# 9        Hashing               Seed     Hamming Distance
# 1         BWT-FM    Backward Search     Hamming Distance
# 2         BWT-FM    Backward Search                Local
# 4        Hashing               Seed     Non-DP Heuristic
# 10       Hashing               Seed                Local
# 6   Suffix Array               Seed                Local
# 11       Hashing               Seed               Global
# 12        BWT-FM               Seed     Non-DP Heuristic
# 0         BWT-FM    Backward Search       Local & Global
# 13  Suffix Array               Seed                Local
# 14       Hashing               Seed                Local
# 15        BWT-FM               Seed       Local & Global
# 5         BWT-FM    Backward Search     Hamming Distance
# 3        Hashing               Seed     Hamming Distance
# 7        Hashing               Seed               Global
# 8        Hashing               Seed               Global

# %%
mem.loc[:,'tools_lower'] = mem['Tools'].str.lower()
memyear = pd.merge(mem, data_year, left_on='tools_lower', right_on='aligner_lower', how='inner')
memyear.loc[:,'average_memory'] = memyear.iloc[:,1:11].mean(axis=1)
memyear_summ = memyear.loc[:,['Tools', 'Year_of_publication', 'average_memory', 'Application', 'Indexing', 'Global_Positioning', 'Pairwise_alignment_2']]
memyear_summ.sort_values(by=['Year_of_publication'], inplace=True)
for i in range(0,16):
    memyear.loc[i,'year_split'] = 'Before 2012' if memyear.loc[i,'Year_of_publication'] < 2012 else '2012 and later'
memyear_new = pd.melt(memyear, id_vars = ['Tools', 'year_split', 'Application', 'Indexing', 'Global_Positioning', 'Pairwise_alignment_2'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'memory')
memyear_summ
# Out:
#          Tools  Year_of_publication  average_memory  Application  \
# 9         rmap                 2008          9.5320          DNA
# 1       Bowtie                 2009          3.1940          DNA
# 2          BWA                 2009          5.7110          DNA
# 4        gsnap                 2010         28.8536          DNA
# 10       smalt                 2010          3.6766          DNA
# 6         last                 2011         15.3589          DNA
# 11        snap                 2011         36.1000          DNA
# 12  soapsplice                 2011          6.0050      RNA-Seq
# 0      Bowtie2                 2012          3.5799          DNA
# 13        STAR                 2013         27.2497      RNA-Seq
# 14     subread                 2013          8.1088      RNA-Seq
# 15     tophat2                 2013          4.0304      RNA-Seq
# 5       hisat2                 2015          4.6941          DNA
# 3         ERNE                 2016          5.3951          DNA
# 7     lordfast                 2018          5.6897          DNA
# 8     minimap2                 2018         12.4488  DNA/RNA-Seq
#
#         Indexing Global_Positioning Pairwise_alignment_2
# 9        Hashing               Seed     Hamming Distance
# 1         BWT-FM    Backward Search     Hamming Distance
# 2         BWT-FM    Backward Search                Local
# 4        Hashing               Seed     Non-DP Heuristic
# 10       Hashing               Seed                Local
# 6   Suffix Array               Seed                Local
# 11       Hashing               Seed               Global
# 12        BWT-FM               Seed     Non-DP Heuristic
# 0         BWT-FM    Backward Search       Local & Global
# 13  Suffix Array               Seed                Local
# 14       Hashing               Seed                Local
# 15        BWT-FM               Seed       Local & Global
# 5         BWT-FM    Backward Search     Hamming Distance
# 3        Hashing               Seed     Hamming Distance
# 7        Hashing               Seed               Global
# 8        Hashing               Seed               Global

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as scp

mwu = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['year_split'] == 'Before 2012'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['year_split'] == '2012 and later'].loc[:,'runtime'],
                             alternative = 'greater')

sns.set_style('white')
sns.set_context('talk')
ax = sns.catplot(data = rtyear_new, x = 'year_split', y = 'runtime', kind = 'violin', 
                 order = ['Before 2012', '2012 and later'])
ax.set(xlabel = 'Year of Publication', ylabel = 'CPU Time (hours)')
plt.plot([0,0,1,1], [73,75,75,73], lw = 1.5, c = 'k')
plt.text(.5, 76, 'p = ' + "{0:.2e}".format(mwu.pvalue), ha = 'center', va = 'bottom', color = 'k')
ax = sns.despine()
#plt.show()
plt.savefig('../figures/Runtime_by_Year.png')
plt.savefig('../figures/Runtime_by_Year.pdf')

# %%
plt.figure(figsize=(15,8))
ax = sns.violinplot(data = rtyear_new, x = 'Tools', y = 'runtime', scale='width', inner='points')
ax.set(xlabel = 'Aligner', ylabel = 'CPU Time (hours)')
ax.set_xticklabels(rotation=40, ha="right", labels=rtyear_new.loc[:,'Tools'])
#plt.show()
plt.savefig('../figures/Runtime_by_Tool.png')
plt.savefig('../figures/Runtime_by_Tool.pdf')

# %%
mwu = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Indexing'] == 'Hashing'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Indexing'] == 'BWT-FM'].loc[:,'runtime'],
                             alternative = 'two-sided')

ax = sns.catplot(data = rtyear_new, x = 'Indexing', y = 'runtime', order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'CPU Time (hours)')
#plt.show()
plt.savefig('../figures/Runtime_by_Index.png')
plt.savefig('../figures/Runtime_by_Index.pdf')

# %%
ax = sns.catplot(data = rtyear_summ, x = 'Indexing', y = 'average_runtime', order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'Average CPU Time (hours)')
#plt.show()
plt.savefig('../figures/Runtime_by_Index_avg.png')
plt.savefig('../figures/Runtime_by_Index_avg.pdf')

# %%
mwu = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Global_Positioning'] == 'Backward Search'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Global_Positioning'] == 'Seed'].loc[:,'runtime'],
                             alternative = 'two-sided')

ax = sns.catplot(data = rtyear_new, x = 'Global_Positioning', y = 'runtime', order=['Seed','Backward Search'])
ax.set(xlabel = 'Global Positioning', ylabel = 'CPU Time (hours)')
plt.plot([0,0,1,1], [63,65,65,63], lw = 1.5, c = 'k')
plt.text(.5, 66, 'p = ' + "{0:.2e}".format(mwu.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.show()
plt.savefig('../figures/Runtime_by_Global.png')
plt.savefig('../figures/Runtime_by_Global.pdf')

# %%
ax = sns.catplot(data = rtyear_summ, x = 'Global_Positioning', y = 'average_runtime', 
                 order=['Seed', 'Backward Search'])
ax.set(xlabel = 'Global Positioning', ylabel = 'Average CPU Time (hours)')
#plt.show()
plt.savefig('../figures/Runtime_by_Global_avg.png')
plt.savefig('../figures/Runtime_by_Global_avg.pdf')

# %%
mwu1 = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Local & Global'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Hamming Distance'].loc[:,'runtime'],
                             alternative = 'greater')
mwu2 = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Hamming Distance'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Local'].loc[:,'runtime'],
                             alternative = 'less')
mwu3 = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Local'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Non-DP Heuristic'].loc[:,'runtime'],
                             alternative = 'less')
mwu4 = scp.stats.mannwhitneyu(rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Non-DP Heuristic'].loc[:,'runtime'], 
                              rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Global'].loc[:,'runtime'],
                             alternative = 'greater')

ax = sns.violinplot(data = rtyear_new, x = 'Pairwise_alignment_2', y = 'runtime', hue = 'Global_Positioning', 
                    split=True, scale='count', hue_order=['Seed','Backward Search'],
                    order=['Local','Hamming Distance','Global','Non-DP Heuristic','Local & Global'],
                    inner=None)
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'CPU Time (hours)')
plt.legend(title='Global Positioning', loc='center left', bbox_to_anchor=(1, .5))
ax.set_xticklabels(rotation=40, ha="right", labels=['Local','Hamming Distance','Global',
                                                    'Non-DP Heuristic','Local & Global'])
#plt.plot([0,0,1,1], [58,60,60,58], lw = 1.5, c = 'k')
#plt.text(.5, 61, 'p = ' + "{0:.2e}".format(mwu1.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.plot([1,1,2,2], [65,67,67,65], lw = 1.5, c = 'k')
#plt.text(1.5, 68, 'p = ' + "{0:.2e}".format(mwu2.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.plot([2,2,3,3], [72,74,74,72], lw = 1.5, c = 'k')
#plt.text(2.5, 75, 'p = ' + "{0:.2e}".format(mwu3.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.plot([3,3,4,4], [65,67,67,65], lw = 1.5, c = 'k')
#plt.text(3.5, 68, 'p = ' + "{0:.2e}".format(mwu4.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.show()

plt.savefig('../figures/Runtime_by_Local.png')
plt.savefig('../figures/Runtime_by_Local.pdf')

# %%
ax = sns.catplot(data = rtyear_summ, x = 'Pairwise_alignment_2', y = 'average_runtime', hue = 'Global_Positioning',
                hue_order=['Seed','Backward Search'],
                order=['Local','Hamming Distance','Global','Non-DP Heuristic','Local & Global'])
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Average CPU Time (hours)')
ax._legend.set_title('Global Positioning')
ax.set_xticklabels(rotation=40, ha="right")
#plt.show()

plt.savefig('../figures/Runtime_by_Local_avg.png')
plt.savefig('../figures/Runtime_by_Local_avg.pdf')

# %%
ax = sns.catplot(data = rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Local'], x = 'Global_Positioning', 
                y = 'runtime', hue = 'Indexing', hue_order=['Hashing','BWT-FM','Suffix Array'], 
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')
ax.set(xlabel = 'Global Positioning', ylabel = 'CPU Time (hours)', title = 'Tools using Local Pairwise Alignment')

plt.savefig('../figures/Runtime_using_Local.png')
plt.savefig('../figures/Runtime_using_Local.pdf')

# %%
ax = sns.catplot(data = rtyear_summ.loc[rtyear_summ['Pairwise_alignment_2'] == 'Local'], x = 'Global_Positioning', 
                y = 'average_runtime', hue = 'Indexing', hue_order=['Hashing','BWT-FM','Suffix Array'],
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')
ax.set(xlabel = 'Global Positioning', ylabel = 'Average CPU Time (hours)', title = 'Tools using Local Pairwise Alignment')

plt.savefig('../figures/Runtime_using_Local_avg.png')
plt.savefig('../figures/Runtime_using_Local_avg.pdf')

# %%
ax = sns.catplot(data = rtyear_new.loc[rtyear_new['Pairwise_alignment_2'] == 'Hamming Distance'],
                 x = 'Global_Positioning', y = 'runtime', hue = 'Indexing', order=['Seed','Backward Search'],
                 hue_order=['Hashing','BWT-FM'])
ax._legend.set_title('Indexing Algorithm')

ax.set(xlabel = 'Global Positioning', ylabel = 'CPU Time (hours)', title = 'Tools using Hamming Distance Pairwise Alignment')

plt.savefig('../figures/Runtime_using_HD.png')
plt.savefig('../figures/Runtime_using_HD.pdf')

# %%
ax = sns.catplot(data = rtyear_summ.loc[rtyear_summ['Pairwise_alignment_2'] == 'Hamming Distance'],
                 x = 'Global_Positioning', y = 'average_runtime', hue = 'Indexing', 
                 order=['Seed','Backward Search'], hue_order=['Hashing','BWT-FM'])
ax._legend.set_title('Indexing Algorithm')

ax.set(xlabel = 'Global Positioning', ylabel = 'Average CPU Time (hours)', title = 'Tools using Hamming Distance Pairwise Alignment')

plt.savefig('../figures/Runtime_using_HD_avg.png')
plt.savefig('../figures/Runtime_using_HD_avg.pdf')

# %%
test = rtyear_new.groupby(['Global_Positioning','Pairwise_alignment_2']).mean()
#test = rtyear_new.pivot(index = 'global_alignment_algorithm', columns = 'local', values = 'runtime')
test = test.unstack(level = -1)
test
# Out:
#                        runtime                                             \
# Pairwise_alignment_2    Global Hamming Distance      Local Local & Global
# Global_Positioning
# Backward Search            NaN         3.630463   6.239311       4.973137
# Seed                  1.080196        10.739059  13.668802      27.529830
#
#
# Pairwise_alignment_2 Non-DP Heuristic
# Global_Positioning
# Backward Search                   NaN
# Seed                         20.31755

# %%
mwu = scp.stats.mannwhitneyu(memyear_new.loc[rtyear_new['year_split'] == 'Before 2012'].loc[:,'memory'], 
                              memyear_new.loc[rtyear_new['year_split'] == '2012 and later'].loc[:,'memory'],
                             alternative = 'greater')

ax = sns.catplot(data = memyear_new, x = 'year_split', y = 'memory', kind = 'violin', 
                 order = ['Before 2012', '2012 and later'])
ax.set(xlabel = 'Year of Publication', ylabel = 'Memory (GB)')
plt.plot([0,0,1,1], [50,52,52,50], lw = 1.5, c = 'k')
plt.text(.5, 53, 'p = ' + "{0:.2e}".format(mwu.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.show()

plt.savefig('../figures/Memory_by_Year.png')
plt.savefig('../figures/Memory_by_Year.pdf')

# %%
plt.figure(figsize=(15,8))
ax = sns.violinplot(data = memyear_new, x = 'Tools', y = 'memory', scale='width', inner='points')
ax.set(xlabel = 'Aligner', ylabel = 'Memory (GB)')
ax.set_xticklabels(rotation=40, ha="right", labels=memyear_new.loc[:,'Tools'])

#plt.show()
plt.savefig('../figures/Memory_by_Tool.png')
plt.savefig('../figures/Memory_by_Tool.pdf')

# %%
mwu1 = scp.stats.mannwhitneyu(memyear_new.loc[memyear_new['Indexing'] == 'BWT-FM'].loc[:,'memory'], 
                              memyear_new.loc[memyear_new['Indexing'] == 'Suffix Array'].loc[:,'memory'],
                             alternative = 'less')

mwu2 = scp.stats.mannwhitneyu(memyear_new.loc[memyear_new['Indexing'] == 'BWT-FM'].loc[:,'memory'], 
                              memyear_new.loc[memyear_new['Indexing'] == 'Hashing'].loc[:,'memory'],
                             alternative = 'less')

ax = sns.catplot(data = memyear_new, x = 'Indexing', y = 'memory', order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'Memory (GB)')

plt.plot([0,0,1,1], [40,42,42,40], lw = 1.5, c = 'k')
plt.text(.5, 43, 'p = ' + "{0:.2e}".format(mwu2.pvalue), ha = 'center', va = 'bottom', color = 'k')
plt.plot([1,1,2,2], [44,46,46,44], lw = 1.5, c = 'k')
plt.text(1.5, 47, 'p = ' + "{0:.2e}".format(mwu1.pvalue), ha = 'center', va = 'bottom', color = 'k')

#plt.show()

plt.savefig('../figures/Memory_by_Index.png')
plt.savefig('../figures/Memory_by_Index.pdf')

# %%
ax = sns.catplot(data = memyear_summ, x = 'Indexing', y = 'average_memory', 
                 order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'Average Memory (GB)')
#plt.show()

plt.savefig('../figures/Memory_by_Index_avg.png')
plt.savefig('../figures/Memory_by_Index_avg.pdf')

# %%
mwu = scp.stats.mannwhitneyu(memyear_new.loc[memyear_new['Global_Positioning'] == 'Backward Search'].loc[:,'memory'], 
                              memyear_new.loc[memyear_new['Global_Positioning'] == 'Seed'].loc[:,'memory'],
                             alternative = 'less')

ax = sns.catplot(data = memyear_new, x = 'Global_Positioning', y = 'memory', order=['Seed','Backward Search'])
ax.set(xlabel = 'Global Positioning', ylabel = 'Memory (GB)')
plt.plot([0,0,1,1], [40,42,42,40], lw = 1.5, c = 'k')
plt.text(.5, 43, 'p = ' + "{0:.2e}".format(mwu.pvalue), ha = 'center', va = 'bottom', color = 'k')
#plt.show()

plt.savefig('../figures/Memory_by_Global.png')
plt.savefig('../figures/Memory_by_Global.pdf')

# %%
ax = sns.catplot(data = memyear_summ, x = 'Global_Positioning', y = 'average_memory', 
                 order=['Seed','Backward Search'])
ax.set(xlabel = 'Global Positioning', ylabel = 'Average Memory (GB)')
#plt.show()
plt.savefig('../figures/Memory_by_Global_avg.png')
plt.savefig('../figures/Memory_by_Global_avg.pdf')

# %%
ax = sns.violinplot(data = memyear_new, x = 'Pairwise_alignment_2', y = 'memory', hue = 'Global_Positioning', 
                    split=True, scale='count', inner = None, hue_order=['Seed','Backward Search'],
                    order=['Local','Hamming Distance','Global','Non-DP Heuristic','Local & Global'])
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Memory (GB)')
#ax._legend.set_title('Global Positioning')
plt.legend(title='Global Positioning', loc='center left', bbox_to_anchor=(1, .5))
ax.set_xticklabels(rotation=40, ha="right", labels=['Local','Hamming Distance','Global',
                                                    'Non-DP Heuristic','Local & Global'])
#plt.show()

plt.savefig('../figures/Memory_by_Local.png')
plt.savefig('../figures/Memory_by_Local.pdf')

# %%
ax = sns.catplot(data = memyear_summ, x = 'Pairwise_alignment_2', y = 'average_memory', hue = 'Global_Positioning',
                hue_order=['Seed','Backward Search'], 
                 order=['Local','Hamming Distance','Global','Non-DP Heuristic','Local & Global'])
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Average Memory (GB)')
ax._legend.set_title('Global Positioning')
ax.set_xticklabels(rotation=40, ha="right")
#plt.show()

plt.savefig('../figures/Memory_by_Local_avg.png')
plt.savefig('../figures/Memory_by_Local_avg.pdf')

# %%
ax = sns.catplot(data = memyear_new.loc[memyear_new['Pairwise_alignment_2'] == 'Local'], x = 'Global_Positioning', 
                y = 'memory', hue = 'Indexing', hue_order=['Hashing','BWT-FM','Suffix Array'],
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')
ax.set(xlabel = 'Global Positioning', ylabel = 'Memory (GB)', title = 'Tools using Local Pairwise Alignment')

plt.savefig('../figures/Memory_using_Local.png')
plt.savefig('../figures/Memory_using_Local.pdf')

# %%
ax = sns.catplot(data = memyear_summ.loc[memyear_summ['Pairwise_alignment_2'] == 'Local'], x = 'Global_Positioning', 
                y = 'average_memory', hue = 'Indexing', hue_order=['Hashing','BWT-FM','Suffix Array'], 
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')
ax.set(xlabel = 'Global Positioning', ylabel = 'Average Memory (GB)', title = 'Tools using Local Pairwise Alignment')

plt.savefig('../figures/Memory_using_Local_avg.png')
plt.savefig('../figures/Memory_using_Local_avg.pdf')

# %%
ax = sns.catplot(data = memyear_new.loc[memyear_new['Pairwise_alignment_2'] == 'Hamming Distance'],
                 x = 'Global_Positioning', y = 'memory', hue = 'Indexing', hue_order=['Hashing','BWT-FM'],
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')

ax.set(xlabel = 'Global Positioning', ylabel = 'Memory (GB)', title = 'Tools using Hamming Distance Pairwise Alignment')

plt.savefig('../figures/Memory_using_HD.png')
plt.savefig('../figures/Memory_using_HD.pdf')

# %%
ax = sns.catplot(data = memyear_summ.loc[memyear_summ['Pairwise_alignment_2'] == 'Hamming Distance'],
                 x = 'Global_Positioning', y = 'average_memory', hue = 'Indexing', hue_order=['Hashing','BWT-FM'],
                order=['Seed','Backward Search'])
ax._legend.set_title('Indexing Algorithm')

ax.set(xlabel = 'Global Positioning', ylabel = 'Average Memory (GB)', title = 'Tools using Hamming Distance Pairwise Alignment')

plt.savefig('../figures/Memory_using_HD_avg.png')
plt.savefig('../figures/Memory_using_HD_avg.pdf')

# %%
test = memyear_new.groupby(['Global_Positioning','Pairwise_alignment_2']).mean()
#test = rtyear_new.pivot(index = 'global_alignment_algorithm', columns = 'local', values = 'runtime')
test = test.unstack(level = -1)
test
# Out:
#                        memory                                           \
# Pairwise_alignment_2   Global Hamming Distance    Local Local & Global
# Global_Positioning
# Backward Search           NaN          3.94405   5.7110         3.5799
# Seed                  18.0795          7.46355  13.5985         4.0304
#
#
# Pairwise_alignment_2 Non-DP Heuristic
# Global_Positioning
# Backward Search                   NaN
# Seed                          17.4293

# %%
#rtyear_summ.head()
#memyear_summ.head()
rtvm = pd.merge(rtyear_summ, memyear_summ, 
                on=['Tools','Year_of_publication','Application','Indexing','Global_Positioning','Pairwise_alignment_2'],
                how='inner')
rtvm.loc[:,'Global_Pairwise'] = rtvm.loc[:,'Global_Positioning'] + " + " + rtvm.loc[:,'Pairwise_alignment_2']
#rtvm
ax = sns.scatterplot(data=rtvm, x = 'average_runtime', y = 'average_memory', hue = 'Global_Pairwise', 
                    hue_order=['Seed + Local','Seed + Hamming Distance',
                              'Seed + Global','Seed + Non-DP Heuristic',
                              'Seed + Local & Global','Backward Search + Local',
                               'Backward Search + Hamming Distance','Backward Search + Local & Global'],
                    legend='brief')
handles,labels = ax.get_legend_handles_labels()
ax.set(xlabel='Average CPU Time (Hours)', ylabel='Average Memory (GB)')
legend = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
legend.texts[0].set_text('Global Positioning + Pairwise Alignment')
#plt.show()

plt.savefig('../figures/Memory_vs_Runtime.png')
plt.savefig('../figures/Memory_vs_Runtime.pdf')

# %%
data_index = data[['Aligner', 'Indexing']]
data_index.loc[:,'aligner_lower'] = data_index.loc[:,'Aligner'].str.lower()
idx_rt.loc[:,'tools_lower'] = idx_rt.loc[:,'Tools'].str.lower()
rtidx = pd.merge(idx_rt, data_index, left_on='tools_lower', right_on='aligner_lower', how='inner')
rtidx = rtidx.dropna()
t = pd.DatetimeIndex(rtidx.loc[:,'Runtime'])
rtidx.loc[:,'Runtime (minutes)'] = t.hour*60 + t.minute
rtidx
# Out:
# /Users/jrotman/anaconda2/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/jrotman/anaconda2/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#          Tools  Runtime  Virtual Mem (G) tools_lower     Aligner  \
# 0      bowtie2  1:53:39            5.398     bowtie2     Bowtie2
# 1       bowtie  1:42:21            5.395      bowtie      Bowtie
# 2          bwa  1:10:43            4.448         bwa         BWA
# 3         erne  6:52:25           12.956        erne        ERNE
# 4        gsnap  1:08:32           19.561       gsnap       GSNAP
# 5       hisat2  1:07:14            5.394      hisat2      HISAT2
# 6         last  0:55:16           28.148        last        LAST
# 7     lordfast  1:04:37            5.423    lordfast    lordFAST
# 8       MOSAIK  0:01:09            6.688      mosaik      MOSAIK
# 9     segemehl  1:26:45           57.773    segemehl    segemehl
# 10       smalt  0:01:58            6.668       smalt       SMALT
# 11        snap  4:04:26           39.313        snap        SNAP
# 12  soapsplice  0:56:13            6.005  soapsplice  SOAPSplice
# 13        STAR  1:30:01           33.477        star        STAR
# 14     subread  0:18:53            6.853     subread     Subread
# 15     tophat2  1:40:46            5.398     tophat2     TopHat2
#
#         Indexing aligner_lower  Runtime (minutes)
# 0         BWT-FM       bowtie2                113
# 1         BWT-FM        bowtie                102
# 2         BWT-FM           bwa                 70
# 3        Hashing          erne                412
# 4        Hashing         gsnap                 68
# 5         BWT-FM        hisat2                 67
# 6   Suffix Array          last                 55
# 7        Hashing      lordfast                 64
# 8        Hashing        mosaik                  1
# 9   Suffix Array      segemehl                 86
# 10       Hashing         smalt                  1
# 11       Hashing          snap                244
# 12        BWT-FM    soapsplice                 56
# 13  Suffix Array          star                 90
# 14       Hashing       subread                 18
# 15        BWT-FM       tophat2                100

# %%
ax = sns.catplot(data = rtidx, x = 'Indexing', y = 'Runtime (minutes)', order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'CPU Time (minutes)')

plt.savefig('../figures/Indexing_by_Runtime.png')
plt.savefig('../figures/Indexing_by_Runtime.pdf')

# %%
ax = sns.catplot(data = rtidx, x = 'Indexing', y = 'Virtual Mem (G)')
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'Memory (GB)')

plt.savefig('../figures/Indexing_by_Memory.png')
plt.savefig('../figures/Indexing_by_Memory.pdf')

# %%
ax = sns.scatterplot(data=rtidx, x = 'Runtime (minutes)', y = 'Virtual Mem (G)', 
                    hue = 'Indexing', hue_order=['Hashing','BWT-FM','Suffix Array'])
ax.set(xlabel = 'CPU Time (minutes)', ylabel = 'Memory (GB)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('../figures/Indexing_Memory_vs_Runtime.png')
plt.savefig('../figures/Indexing_Memory_vs_Runtime.pdf')
#plt.show()

# %%
tools = data.loc[:,['Aligner','Indexing','Global_Positioning','Pairwise_alignment_2',
                   'Pairwise_alignment (DP-based?)','fix length seed','Variable length seed (hybrid seeding)',
                   'spaced seed','chain_of_seeds']]
tools.head()
# Out:
#       Aligner Indexing Global_Positioning Pairwise_alignment_2  \
# 0     Bismark   BWT-FM    Backward Search     Hamming Distance
# 1        BRAT  Hashing               Seed     Hamming Distance
# 2     BRAT-BW   BWT-FM    Backward Search     Hamming Distance
# 3   BS-Seeker   BWT-FM    Backward Search     Hamming Distance
# 4  BS-Seeker2   BWT-FM    Backward Search       Local & Global
#
#   Pairwise_alignment (DP-based?) fix length seed  \
# 0                              N               Y
# 1                              N               Y
# 2                              N               N
# 3                              N               Y
# 4                              Y               Y
#
#   Variable length seed (hybrid seeding) spaced seed chain_of_seeds
# 0                                     N           N              N
# 1                                     N           N              N
# 2                                     Y           N              N
# 3                                     N           N              N
# 4                                     N           N              N

# %%
tools.loc[:,'aligner_lower'] = data_year['Aligner'].str.lower()
seed_info = pd.merge(rtyear, tools, left_on='tools_lower', right_on='aligner_lower', how='inner')
seed_info = seed_info.loc[:,['Tools','ERR009309','ERR013127','ERR013138','ERR045708','ERR050158','ERR162843',
                             'ERR181410','ERR183377','SRR061640','SRR360549','Pairwise_alignment (DP-based?)',
                             'fix length seed','Variable length seed (hybrid seeding)',
                             'spaced seed','chain_of_seeds']]
seed_info
# Out:
#          Tools  ERR009309  ERR013127  ERR013138  ERR045708  ERR050158  \
# 0      Bowtie2   2.364914   4.442126   6.125343   9.481851   4.480202
# 1       Bowtie   3.358317   5.825385   8.749844  12.251327   6.041617
# 2          BWA   4.048227   6.964193   8.374950  10.337639   5.155173
# 3         ERNE   2.066056   5.475683   9.406134  13.734103   8.755687
# 4        gsnap  18.782465  29.469896  40.606409  34.717148  11.450009
# 5       hisat2   0.582257   2.636554   1.459196   1.739013   0.778033
# 6         last  10.140177  16.316454  27.292700  27.709176  23.393876
# 7     lordfast   0.082570   0.168354   0.239144   0.371073   0.184324
# 8     minimap2   0.955566   1.781175   3.408856   2.273320   1.625731
# 9         rmap   7.669205  10.087773  14.721393  21.384636  13.965002
# 10       smalt  12.295481  26.736237  47.018981  60.391744  29.646617
# 11        snap   1.074248   0.682443   1.840848   1.809145   0.830031
# 12  soapsplice  22.753959  38.299319  34.668136  20.422124  13.226813
# 13        STAR   0.923999   1.123721   1.647142   1.591509   0.847372
# 14     subread   0.554908   1.216942   1.656088   2.325297   0.977854
# 15     tophat2  14.036164  23.743464  33.157358  33.304072  33.168864
#
#     ERR162843  ERR181410  ERR183377  SRR061640  SRR360549  \
# 0    6.579199   5.183426   4.279699   2.942086   3.852528
# 1    7.729104   5.987389   4.563028   1.797393   4.718723
# 2    7.040740   6.394736   4.827655   3.171607   6.078192
# 3         NaN  11.730733   8.590035   7.333813   7.445680
# 4   17.150793  16.579589  13.286443  10.444190  16.757750
# 5    1.107651   0.944994   0.820202   0.604172   0.915061
# 6   34.322943  17.217662  14.567814  13.563960  17.689251
# 7    0.261441   0.223871   0.196660   0.154788   0.203453
# 8    2.278983   1.980141   1.624609   1.086941   1.648935
# 9   17.182582  12.655798   9.048157  10.189939  12.599718
# 10  38.529345  33.415141  27.376229  16.051896  30.176233
# 11   1.151981   1.163371   0.944356   0.905404   1.254126
# 12  12.402703  12.573973   9.232410   7.840413  25.686463
# 13   1.066349   0.932475   0.768034   0.635062   0.910041
# 14   1.511746   1.157220   0.979500   0.911420   1.163473
# 15  18.471329  18.964149  33.405431  33.539547  33.507919
#
#    Pairwise_alignment (DP-based?) fix length seed  \
# 0                               Y               Y
# 1                               N               Y
# 2                               Y               N
# 3                               N               Y
# 4                               N               Y
# 5                               N               Y
# 6                               Y               N
# 7                               Y               Y
# 8                               Y               Y
# 9                               N               Y
# 10                              Y               Y
# 11                              Y               Y
# 12                              N               Y
# 13                              Y               N
# 14                              Y               Y
# 15                              Y               Y
#
#    Variable length seed (hybrid seeding) spaced seed chain_of_seeds
# 0                                      N           N              N
# 1                                      N           N              N
# 2                                      Y           N              N
# 3                                      N           N              N
# 4                                      N           N              N
# 5                                      N           N              N
# 6                                      Y           N              N
# 7                                      N           N              N
# 8                                      N           N              N
# 9                                      N           N              N
# 10                                     N           N              N
# 11                                     N           N              N
# 12                                     N           N              N
# 13                                     Y           N              N
# 14                                     N           Y              N
# 15                                     N           N              N

# %%
seed_all = pd.melt(seed_info, id_vars = ['Tools', 'Pairwise_alignment (DP-based?)',
                             'fix length seed','Variable length seed (hybrid seeding)',
                             'spaced seed','chain_of_seeds'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'runtime')
seed_all.head()
# Out:
#      Tools Pairwise_alignment (DP-based?) fix length seed  \
# 0  Bowtie2                              Y               Y
# 1   Bowtie                              N               Y
# 2      BWA                              Y               N
# 3     ERNE                              N               Y
# 4    gsnap                              N               Y
#
#   Variable length seed (hybrid seeding) spaced seed chain_of_seeds   variable  \
# 0                                     N           N              N  ERR009309
# 1                                     N           N              N  ERR009309
# 2                                     Y           N              N  ERR009309
# 3                                     N           N              N  ERR009309
# 4                                     N           N              N  ERR009309
#
#      runtime
# 0   2.364914
# 1   3.358317
# 2   4.048227
# 3   2.066056
# 4  18.782465

# %%
ax = sns.catplot(data = seed_all, x = 'Pairwise_alignment (DP-based?)', y = 'runtime')
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'fix length seed', y = 'runtime')
ax.set(xlabel = 'Fixed Length Seed', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'Variable length seed (hybrid seeding)', y = 'runtime')
ax.set(xlabel = 'Hybrid Seeding', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'spaced seed', y = 'runtime')
ax.set(xlabel = 'Spaced Seed', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'chain_of_seeds', y = 'runtime')
ax.set(xlabel = 'Chain of Seeds', ylabel = 'Runtime (hours)')
plt.show()

# %%
seed_mem = pd.merge(memyear, tools, left_on='tools_lower', right_on='aligner_lower', how='inner')
seed_mem = seed_info.loc[:,['Tools','ERR009309','ERR013127','ERR013138','ERR045708','ERR050158','ERR162843',
                             'ERR181410','ERR183377','SRR061640','SRR360549','Pairwise_alignment (DP-based?)',
                             'fix length seed','Variable length seed (hybrid seeding)',
                             'spaced seed','chain_of_seeds']]
seed_mem
# Out:
#          Tools  ERR009309  ERR013127  ERR013138  ERR045708  ERR050158  \
# 0      Bowtie2   2.364914   4.442126   6.125343   9.481851   4.480202
# 1       Bowtie   3.358317   5.825385   8.749844  12.251327   6.041617
# 2          BWA   4.048227   6.964193   8.374950  10.337639   5.155173
# 3         ERNE   2.066056   5.475683   9.406134  13.734103   8.755687
# 4        gsnap  18.782465  29.469896  40.606409  34.717148  11.450009
# 5       hisat2   0.582257   2.636554   1.459196   1.739013   0.778033
# 6         last  10.140177  16.316454  27.292700  27.709176  23.393876
# 7     lordfast   0.082570   0.168354   0.239144   0.371073   0.184324
# 8     minimap2   0.955566   1.781175   3.408856   2.273320   1.625731
# 9         rmap   7.669205  10.087773  14.721393  21.384636  13.965002
# 10       smalt  12.295481  26.736237  47.018981  60.391744  29.646617
# 11        snap   1.074248   0.682443   1.840848   1.809145   0.830031
# 12  soapsplice  22.753959  38.299319  34.668136  20.422124  13.226813
# 13        STAR   0.923999   1.123721   1.647142   1.591509   0.847372
# 14     subread   0.554908   1.216942   1.656088   2.325297   0.977854
# 15     tophat2  14.036164  23.743464  33.157358  33.304072  33.168864
#
#     ERR162843  ERR181410  ERR183377  SRR061640  SRR360549  \
# 0    6.579199   5.183426   4.279699   2.942086   3.852528
# 1    7.729104   5.987389   4.563028   1.797393   4.718723
# 2    7.040740   6.394736   4.827655   3.171607   6.078192
# 3         NaN  11.730733   8.590035   7.333813   7.445680
# 4   17.150793  16.579589  13.286443  10.444190  16.757750
# 5    1.107651   0.944994   0.820202   0.604172   0.915061
# 6   34.322943  17.217662  14.567814  13.563960  17.689251
# 7    0.261441   0.223871   0.196660   0.154788   0.203453
# 8    2.278983   1.980141   1.624609   1.086941   1.648935
# 9   17.182582  12.655798   9.048157  10.189939  12.599718
# 10  38.529345  33.415141  27.376229  16.051896  30.176233
# 11   1.151981   1.163371   0.944356   0.905404   1.254126
# 12  12.402703  12.573973   9.232410   7.840413  25.686463
# 13   1.066349   0.932475   0.768034   0.635062   0.910041
# 14   1.511746   1.157220   0.979500   0.911420   1.163473
# 15  18.471329  18.964149  33.405431  33.539547  33.507919
#
#    Pairwise_alignment (DP-based?) fix length seed  \
# 0                               Y               Y
# 1                               N               Y
# 2                               Y               N
# 3                               N               Y
# 4                               N               Y
# 5                               N               Y
# 6                               Y               N
# 7                               Y               Y
# 8                               Y               Y
# 9                               N               Y
# 10                              Y               Y
# 11                              Y               Y
# 12                              N               Y
# 13                              Y               N
# 14                              Y               Y
# 15                              Y               Y
#
#    Variable length seed (hybrid seeding) spaced seed chain_of_seeds
# 0                                      N           N              N
# 1                                      N           N              N
# 2                                      Y           N              N
# 3                                      N           N              N
# 4                                      N           N              N
# 5                                      N           N              N
# 6                                      Y           N              N
# 7                                      N           N              N
# 8                                      N           N              N
# 9                                      N           N              N
# 10                                     N           N              N
# 11                                     N           N              N
# 12                                     N           N              N
# 13                                     Y           N              N
# 14                                     N           Y              N
# 15                                     N           N              N

# %%
mem_all = pd.melt(seed_mem, id_vars = ['Tools', 'Pairwise_alignment (DP-based?)',
                             'fix length seed','Variable length seed (hybrid seeding)',
                             'spaced seed','chain_of_seeds'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'memory')
mem_all.head()
# Out:
#      Tools Pairwise_alignment (DP-based?) fix length seed  \
# 0  Bowtie2                              Y               Y
# 1   Bowtie                              N               Y
# 2      BWA                              Y               N
# 3     ERNE                              N               Y
# 4    gsnap                              N               Y
#
#   Variable length seed (hybrid seeding) spaced seed chain_of_seeds   variable  \
# 0                                     N           N              N  ERR009309
# 1                                     N           N              N  ERR009309
# 2                                     Y           N              N  ERR009309
# 3                                     N           N              N  ERR009309
# 4                                     N           N              N  ERR009309
#
#       memory
# 0   2.364914
# 1   3.358317
# 2   4.048227
# 3   2.066056
# 4  18.782465

# %%
ax = sns.catplot(data = mem_all, x = 'Pairwise_alignment (DP-based?)', y = 'memory')
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Memory (GB)')
plt.show()

# %%
ax = sns.catplot(data = mem_all, x = 'Variable length seed (hybrid seeding)', y = 'memory')
ax.set(xlabel = 'Variable Length Seed', ylabel = 'Memory (GB)')
plt.show()

# %%
ax = sns.catplot(data = mem_all, x = 'spaced seed', y = 'memory')
ax.set(xlabel = 'Spaced Seed', ylabel = 'Memory (GB)')
plt.show()
