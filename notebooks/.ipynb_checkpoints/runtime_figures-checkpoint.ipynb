# %%
import pandas as pd
data=pd.read_csv('../data/Table1.csv')
data['age']=2019-data['Year_of_publication']+1
data['citation_per_year']=data['Number_of_citations']/data['age']
data.head(3)
# Out:
#    Unnamed: 0  Year_of_publication Aligner  \
# 0         1.0                 2001   SSAHA
# 1         2.0                 2002    Blat
# 2         3.0                 2003  BLASTZ
#
#                                             URL  \
# 0  https://www.sanger.ac.uk/science/tools/ssaha
# 1        https://genome.ucsc.edu/cgi-bin/hgBlat
# 2            https://www.bx.psu.edu/miller_lab/
#
#                                             Citation  Number_of_citations  \
# 0  SSAHA: a fast search method for large DNA data...               1093.0
# 1                 BLAT—the BLAST-like alignment tool               6935.0
# 2                 Human–Mouse Alignments with BLASTZ               1339.0
#
#   Indexing_algorithm global_alignment_algorithm wrapper  \
# 0            hashing                       seed       N
# 1            hashing                       seed       N
# 2            hashing                       seed       Y
#
#                         wrapper_of the original tool  ... fix length seed  \
# 0                                                NaN  ...               Y
# 1                                                NaN  ...               Y
# 2  A wrapper of PipMaker—A Web Server for Alignin...  ...               Y
#
#   hybrid seeding (search for keyword variable)  \
# 0                                            N
# 1                                            N
# 2                                            N
#
#   spaced seed (search for spaced or gapped) chain_of_seeds Technology  \
# 0                                         N              N        DNA
# 1                                         N              Y        DNA
# 2                                         N              N        DNA
#
#    email - first author    email - last author  \
# 0      zn1@sanger.ac.uk  mullikin@mail.nih.gov
# 1     kent@soe.ucsc.edu                 ------
# 2  webb@bio.cse.psu.edu           wcm2@psu.edu
#
#                                             Verified age citation_per_year
# 0                             base-by-base alignment  19         57.526316
# 1  No hamming distance, it keeps increasing the s...  18        385.277778
# 2  They change the alignment scoring of BlastZ in...  17         78.764706
#
# [3 rows x 22 columns]

# %%
rt = pd.read_csv('../data/compare.tools.runtime.hours.csv')
idx_rt = pd.read_csv('../data/compare.tools.index.csv')
# Out:
#   Aligner Indexing_algorithm global_alignment_algorithm  \
# 0   SSAHA            hashing                       seed
# 1    Blat            hashing                       seed
# 2  BLASTZ            hashing                       seed
# 3      C4            hashing                       seed
# 4    GMAP            hashing                       seed
#
#                           local Pairwise_alignment (DP-based?)  \
# 0              hamming distance                              Y
# 1              Non-DP heuristic                              N
# 2                            SW                              Y
# 3  hamming distance, SW, and NW                              Y
# 4                            NW                              Y
#
#   fix length seed hybrid seeding (search for keyword variable)  \
# 0               Y                                            N
# 1               Y                                            N
# 2               Y                                            N
# 3               Y                                            N
# 4               N                                            Y
#
#   spaced seed (search for spaced or gapped) chain_of_seeds
# 0                                         N              N
# 1                                         N              Y
# 2                                         N              N
# 3                                         N              N
# 4                                         N              Y

# %%
data_year = data.loc[:,['Year_of_publication', 'Aligner', 'Technology', 'Indexing_algorithm', 'global_alignment_algorithm', 'local']]
data_year.loc[:,'aligner_lower'] = data_year['Aligner'].str.lower()
rt.loc[:,'tools_lower'] = rt['Tools'].str.lower()
rtyear = pd.merge(rt, data_year, left_on='tools_lower', right_on='aligner_lower', how='inner')
rtyear.loc[:,'average_runtime'] = rtyear.iloc[:,1:11].mean(axis=1)
rtyear_summ = rtyear.loc[:,['Tools', 'Year_of_publication', 'average_runtime', 'Technology', 'Indexing_algorithm', 'global_alignment_algorithm', 'local']]
rtyear_summ.sort_values(by=['Year_of_publication'], inplace=True)
for i in range(0,16):
    rtyear.loc[i,'year_split'] = 'Before 2012' if rtyear.loc[i,'Year_of_publication'] < 2012 else '2012 and later'
rtyear_new = pd.melt(rtyear, id_vars = ['Tools', 'year_split', 'Technology', 'Indexing_algorithm', 'global_alignment_algorithm', 'local'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'runtime')
rtyear_new.head()
# Out:
#      Tools      year_split Technology Indexing_algorithm  \
# 0  Bowtie2  2012 and later        DNA             BWT-FM
# 1   Bowtie     Before 2012        DNA             BWT-FM
# 2      BWA     Before 2012        DNA             BWT-FM
# 3     ERNE  2012 and later        DNA            hashing
# 4    gsnap     Before 2012        DNA            hashing
#
#   global_alignment_algorithm             local   variable    runtime
# 0            Backward Search           SW & NW  ERR009309   2.364914
# 1            Backward Search  hamming distance  ERR009309   3.358317
# 2            Backward Search                SW  ERR009309   4.048227
# 3                       seed  hamming distance  ERR009309   2.066056
# 4                       seed  Non-DP heuristic  ERR009309  18.782465

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style='whitegrid')
ax = sns.catplot(data = rtyear_new, x = 'year_split', y = 'runtime', kind = 'violin', 
                 order = ['Before 2012', '2012 and later'])
ax.set(xlabel = 'Year of Publication', ylabel = 'Runtime (hours)')
plt.show()
#plt.savefig('../figures/Runtime_by_YoP.png')

# %%
ax = sns.catplot(data = rtyear_new, x = 'Indexing_algorithm', y = 'runtime')
ax.set(xlabel = 'Indexing Algorithm', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = rtyear_new, x = 'global_alignment_algorithm', y = 'runtime')
ax.set(xlabel = 'Global Alignment', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = rtyear_new, x = 'local', y = 'runtime')
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Runtime (hours)')
ax.set_xticklabels(rotation=40, ha="right")
plt.show()

# %%
test = rtyear_new.groupby(['global_alignment_algorithm','local']).mean()
#test = rtyear_new.pivot(index = 'global_alignment_algorithm', columns = 'local', values = 'runtime')
test = test.unstack(level = -1)
test
# Out:
#                              runtime                                         \
# local                             NW Non-DP heuristic         SW    SW & NW
# global_alignment_algorithm
# Backward Search                  NaN              NaN   6.239311   4.973137
# seed                        1.080196         20.31755  13.668802  27.529830
#
#
# local                      hamming distance
# global_alignment_algorithm
# Backward Search                    3.630463
# seed                              10.739059

# %%
data_index = data[['Aligner', 'Indexing_algorithm']]
data_index.loc[:,'aligner_lower'] = data_index.loc[:,'Aligner'].str.lower()
idx_rt.loc[:,'tools_lower'] = rt.loc[:,'Tools'].str.lower()
rtidx = pd.merge(idx_rt, data_index, left_on='tools_lower', right_on='aligner_lower', how='inner')
rtidx = rtidx.dropna()
t = pd.DatetimeIndex(rtidx.loc[:,'Runtime'])
rtidx.loc[:,'Runtime (minutes)'] = t.hour*60 + t.minute
rtidx
# Out:
# /Users/jrotman/anaconda2/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/jrotman/anaconda2/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#          Tools  Runtime  Virtual Mem (G) tools_lower     Aligner  \
# 0      bowtie2  1:53:39            5.398     bowtie2     Bowtie2
# 1       bowtie  1:42:21            5.395      bowtie      Bowtie
# 2          bwa  1:10:43            4.448         bwa         BWA
# 3         erne  6:52:25           12.956        erne        ERNE
# 4        gsnap  1:08:32           19.561       gsnap       GSNAP
# 5       hisat2  1:07:14            5.394      hisat2      HISAT2
# 6         last  0:55:16           28.148        last        LAST
# 7     lordfast  1:04:37            5.423    lordfast    lordFAST
# 8    novoalign  0:12:45            9.061    minimap2    minimap2
# 9         snap  4:04:26           39.313        rmap        RMAP
# 10  soapsplice  0:56:13            6.005       smalt       Smalt
# 11        STAR  1:30:01           33.477        snap        SNAP
# 12     subread  0:18:53            6.853  soapsplice  SOAPSplice
# 13     tophat2  1:40:46            5.398        star        STAR
#
#    Indexing_algorithm aligner_lower  Runtime (minutes)
# 0              BWT-FM       bowtie2                113
# 1              BWT-FM        bowtie                102
# 2              BWT-FM           bwa                 70
# 3             hashing          erne                412
# 4             hashing         gsnap                 68
# 5              BWT-FM        hisat2                 67
# 6        suffix array          last                 55
# 7             hashing      lordfast                 64
# 8             hashing      minimap2                 12
# 9             hashing          rmap                244
# 10            hashing         smalt                 56
# 11            hashing          snap                 90
# 12             BWT-FM    soapsplice                 18
# 13       suffix array          star                100

# %%
ax = sns.catplot(data = rtidx, x = 'Indexing_algorithm', y = 'Runtime (minutes)')
ax.set(xlabel = 'Indexing Algorithm')
plt.savefig('../figures/Indexing_by_time.png')

# %%
import seaborn as sns

ax = sns.catplot(data = rtidx, x = 'Indexing_algorithm', y = 'Virtual Mem (G)')
ax.set(xlabel = 'Indexing Algorithm')
plt.savefig('../figures/Indexing_by_mem.png')

# %%
ax = sns.scatterplot(data=rtidx, x = 'Runtime (minutes)', y = 'Virtual Mem (G)', 
                    hue = 'Indexing_algorithm')
ax.set(xlabel = 'Indexing Algorithm')
plt.savefig('../figures/Indexing_mem_vs_runtime.png')

# %%
tools = data.loc[:,['Aligner','Indexing_algorithm','global_alignment_algorithm','local',
                   'Pairwise_alignment (DP-based?)','fix length seed','hybrid seeding (search for keyword variable)',
                   'spaced seed (search for spaced or gapped)','chain_of_seeds']]
tools.head()
# Out:
#   Aligner Indexing_algorithm global_alignment_algorithm  \
# 0   SSAHA            hashing                       seed
# 1    Blat            hashing                       seed
# 2  BLASTZ            hashing                       seed
# 3      C4            hashing                       seed
# 4    GMAP            hashing                       seed
#
#                           local Pairwise_alignment (DP-based?)  \
# 0              hamming distance                              Y
# 1              Non-DP heuristic                              N
# 2                            SW                              Y
# 3  hamming distance, SW, and NW                              Y
# 4                            NW                              Y
#
#   fix length seed hybrid seeding (search for keyword variable)  \
# 0               Y                                            N
# 1               Y                                            N
# 2               Y                                            N
# 3               Y                                            N
# 4               N                                            Y
#
#   spaced seed (search for spaced or gapped) chain_of_seeds
# 0                                         N              N
# 1                                         N              Y
# 2                                         N              N
# 3                                         N              N
# 4                                         N              Y

# %%
tools.loc[:,'aligner_lower'] = data_year['Aligner'].str.lower()
seed_info = pd.merge(rtyear, tools, left_on='tools_lower', right_on='aligner_lower', how='inner')
seed_info = seed_info.loc[:,['Tools','ERR009309','ERR013127','ERR013138','ERR045708','ERR050158','ERR162843',
                             'ERR181410','ERR183377','SRR061640','SRR360549','Pairwise_alignment (DP-based?)',
                             'fix length seed','hybrid seeding (search for keyword variable)',
                             'spaced seed (search for spaced or gapped)','chain_of_seeds']]
seed_info.head()
# Out:
#      Tools  ERR009309  ERR013127  ERR013138  ERR045708  ERR050158  ERR162843  \
# 0  Bowtie2   2.364914   4.442126   6.125343   9.481851   4.480202   6.579199
# 1   Bowtie   3.358317   5.825385   8.749844  12.251327   6.041617   7.729104
# 2      BWA   4.048227   6.964193   8.374950  10.337639   5.155173   7.040740
# 3     ERNE   2.066056   5.475683   9.406134  13.734103   8.755687        NaN
# 4    gsnap  18.782465  29.469896  40.606409  34.717148  11.450009  17.150793
#
#    ERR181410  ERR183377  SRR061640  SRR360549 Pairwise_alignment (DP-based?)  \
# 0   5.183426   4.279699   2.942086   3.852528                              Y
# 1   5.987389   4.563028   1.797393   4.718723                              N
# 2   6.394736   4.827655   3.171607   6.078192                              Y
# 3  11.730733   8.590035   7.333813   7.445680                              N
# 4  16.579589  13.286443  10.444190  16.757750                              N
#
#   fix length seed hybrid seeding (search for keyword variable)  \
# 0               Y                                            N
# 1               Y                                            N
# 2               N                                            Y
# 3               Y                                            N
# 4               Y                                            N
#
#   spaced seed (search for spaced or gapped) chain_of_seeds
# 0                                         N              N
# 1                                         N              N
# 2                                         N              N
# 3                                         N              N
# 4                                         N              N

# %%
seed_all = pd.melt(seed_info, id_vars = ['Tools', 'Pairwise_alignment (DP-based?)',
                             'fix length seed','hybrid seeding (search for keyword variable)',
                             'spaced seed (search for spaced or gapped)','chain_of_seeds'], 
        value_vars = ['ERR009309', 'ERR013127', 'ERR013138', 'ERR045708', 'ERR050158', 'ERR162843', 'ERR181410',
                     'ERR183377', 'SRR061640', 'SRR360549'], value_name = 'runtime')
seed_all.head()
# Out:
#      Tools Pairwise_alignment (DP-based?) fix length seed  \
# 0  Bowtie2                              Y               Y
# 1   Bowtie                              N               Y
# 2      BWA                              Y               N
# 3     ERNE                              N               Y
# 4    gsnap                              N               Y
#
#   hybrid seeding (search for keyword variable)  \
# 0                                            N
# 1                                            N
# 2                                            Y
# 3                                            N
# 4                                            N
#
#   spaced seed (search for spaced or gapped) chain_of_seeds   variable  \
# 0                                         N              N  ERR009309
# 1                                         N              N  ERR009309
# 2                                         N              N  ERR009309
# 3                                         N              N  ERR009309
# 4                                         N              N  ERR009309
#
#      runtime
# 0   2.364914
# 1   3.358317
# 2   4.048227
# 3   2.066056
# 4  18.782465

# %%
ax = sns.catplot(data = seed_all, x = 'Pairwise_alignment (DP-based?)', y = 'runtime')
ax.set(xlabel = 'Pairwise Alignment', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'fix length seed', y = 'runtime')
ax.set(xlabel = 'Fixed Length Seed', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'hybrid seeding (search for keyword variable)', y = 'runtime')
ax.set(xlabel = 'Hybrid Seeding', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'spaced seed (search for spaced or gapped)', y = 'runtime')
ax.set(xlabel = 'Spaced Seed', ylabel = 'Runtime (hours)')
plt.show()

# %%
ax = sns.catplot(data = seed_all, x = 'chain_of_seeds', y = 'runtime')
ax.set(xlabel = 'Chain of Seeds', ylabel = 'Runtime (hours)')
plt.show()
