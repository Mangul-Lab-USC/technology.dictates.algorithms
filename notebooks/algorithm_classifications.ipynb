# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

agg = pd.read_csv('../data/aggregated_table1_new.csv')
agg = agg.drop(agg.iloc[:,[0]], axis = 1)
agg = agg.rename(columns={"Index":"source","Global":"type","Pairwise":"target","n":"value"})
agg = agg.dropna()
agg
# Out:
#           source             type                                  target  \
# 0         BWT-FM  Backward Search                 Banded Myers Bit Vector
# 1         BWT-FM  Backward Search  Based on the Wrapper, Local and Global
# 2         BWT-FM  Backward Search                                  Global
# 3         BWT-FM  Backward Search                        Hamming Distance
# 4         BWT-FM  Backward Search                                   Local
# 5         BWT-FM  Backward Search                          Local & Global
# 6         BWT-FM   Chain of Seeds                          Local & Global
# 7         BWT-FM             Seed                                  Global
# 8         BWT-FM             Seed                                   Local
# 9         BWT-FM             Seed                          Local & Global
# 10        BWT-FM             Seed                     Local & Semi-Global
# 11        BWT-FM             Seed                        Non-DP Heuristic
# 12        BWT-ST             Seed                        Hamming Distance
# 13       Hashing   Chain of Seeds                                  Global
# 15       Hashing             Seed                 Banded Myers Bit Vector
# 16       Hashing             Seed                                  Global
# 17       Hashing             Seed                        Hamming Distance
# 18       Hashing             Seed                          Landau-Vishkin
# 19       Hashing             Seed                                   Local
# 20       Hashing             Seed                          Local & Global
# 21       Hashing             Seed                        Non-DP Heuristic
# 22       Hashing             Seed                    Rabin-Karp Algorithm
# 23       Hashing             Seed                             Semi-Global
# 24       Hashing             Seed                               Sparse DP
# 27  Suffix Array  Backward Search                                   Local
# 28  Suffix Array             Seed                                   Local
# 29   Suffix Tree  Backward Search                 Banded Myers Bit Vector
#
#     value
# 0       1
# 1       1
# 2       1
# 3       8
# 4       5
# 5       2
# 6       1
# 7       1
# 8       1
# 9       1
# 10      1
# 11      2
# 12      1
# 13      1
# 15      3
# 16     12
# 17     10
# 18      1
# 19     16
# 20      1
# 21      6
# 22      1
# 23      4
# 24      3
# 27      1
# 28      5
# 29      1

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *

size = dict(width=570, height=300)

#nodes = {
#    'index': ProcessGroup(['Hashing', 'BWT-FM', 'BWT-ST', 'Suffix Array', 'Suffix Tree']),
#    'pairwise': ProcessGroup(['Banded Myers Bit Vector', 'Hamming Distance', 'NW', 'SW', 'Local',
#                             'SW & NW', 'SW & Semi-Global', 'Non-DP Heuristic',
#                             'Hamming Distance, SW, and NW', 'Landau-Vishkin', 'Rabin–Karp Algorithm',
#                             'Sparse Dynamic Programming', 'Semi-Global']),
#}

nodes = {
    'index': ProcessGroup(['Hashing', 'BWT-FM', 'BWT-ST', 'Suffix Array', 'Suffix Tree']),
    'pairwise': ProcessGroup(['Banded Myers Bit Vector', 'Based on the Wrapper, Local and Global', 'Global', 'Local',
                             'Hamming Distance', 'Local & Global', 'Local & Semi-Global', 'Non-DP Heuristic',
                             'Hamming, Local, and Global Alignment', 'Landau-Vishkin', 'Rabin-Karp Algorithm',
                             'Sparse DP', 'Semi-Global']),
}

ordering = [
    ['index'],  
    ['pairwise'],
]

bundles = [
    Bundle('index', 'pairwise'),
]

sdd = SankeyDefinition(nodes, bundles, ordering)
weave(sdd, agg).to_widget(**size)
# Out:
# SankeyWidget(layout=Layout(height='300', width='570'), links=[{'source': 'index^*', 'target': 'pairwise^*', 't…

# %%
index_part = Partition.Simple('process', [
    'Hashing',
    'BWT-FM',
    ('Other', ['BWT-ST', 'Suffix Array', 'Suffix Tree']),
])

#pairwise_part = Partition.Simple('process', [
#    'SW',
#    'NW',
#    'Hamming Distance',
#    'Non-DP Heuristic',
#    ('Multiple Methods', ['SW & NW', 'SW & Semi-Global', 
#                          'Hamming Distance, SW, and NW']),
#    ('Other DP', ['Rabin–Karp Algorithm', 'Landau-Vishkin', 'Sparse Dynamic Programming', 
#                          'Banded Myers Bit Vector', 'Semi-Global', 'Local'])
#])

pairwise_part = Partition.Simple('process', [
    'Local',
    'Hamming Distance',
    'Global',
    'Non-DP Heuristic',
    ('Multiple Methods', ['Based on the Wrapper, Local and Global', 'Local & Global', 'Local & Semi-Global', 
                          'Hamming, Local, and Global Alignment']),
    ('Other DP', ['Rabin-Karp Algorithm', 'Landau-Vishkin', 'Sparse DP', 
                          'Banded Myers Bit Vector', 'Semi-Global'])
])

nodes['index'].partition = index_part
nodes['pairwise'].partition = pairwise_part
weave(sdd, agg).to_widget(**size)
# Out:
# SankeyWidget(groups=[{'id': 'index', 'type': 'process', 'title': '', 'nodes': ['index^Hashing', 'index^BWT-FM'…

# %%
part_by_global = Partition.Simple('type', ['Seed', 'Backward Search', 'Chain of Seeds'])
part_by_index = Partition.Simple('source', ['Hashing', 'BWT-FM', 'Other'])
pal = ['cornflowerblue','darkorange','limegreen']
sdd = SankeyDefinition(nodes, bundles, ordering, flow_partition=part_by_index)
weave(sdd, agg, palette=pal).to_widget(**size)
# Out:
# SankeyWidget(groups=[{'id': 'index', 'type': 'process', 'title': '', 'nodes': ['index^Hashing', 'index^BWT-FM'…

# %%
nodes['global'] = Waypoint(part_by_global)
ordering = [
    ['index'],
    ['global'],
    ['pairwise'],
]

bundles = [
    Bundle('index', 'pairwise', waypoints=['global']),
]

sdd = SankeyDefinition(nodes, bundles, ordering, flow_partition=part_by_index)
weave(sdd, agg, palette=pal).to_widget(**size).auto_save_png('../figures/Sankey_Table1_Tools.png')
# Out:
# SankeyWidget(groups=[{'id': 'index', 'type': 'process', 'title': '', 'nodes': ['index^Hashing', 'index^BWT-FM'…

# %%
data = pd.read_csv('../data/Table1_new.csv')
data.head()
# Out:
#    Unnamed: 0  Year_of_publication     Aligner  \
# 0        43.0                 2011     Bismark
# 1        16.0                 2009        BRAT
# 2        54.0                 2012     BRAT-BW
# 3        32.0                 2010   BS-Seeker
# 4        63.0                 2013  BS-Seeker2
#
#                                                  URL              Citation  \
# 0  https://www.bioinformatics.babraham.ac.uk/proj...  Krueger et al. ‎2011
# 1                    http://compbio.cs.ucr.edu/brat/    Harris et al. 2009
# 2                    http://compbio.cs.ucr.edu/brat/    Harris et al. 2012
# 3              https://github.com/BSSeeker/BSseeker2     Chen et al. ‎2010
# 4              https://github.com/BSSeeker/BSseeker2      Guo et al. ‎2013
#
#    read_length max_read_length_tested  \
# 0  Ultra-short                     50
# 1  Ultra-short                     26
# 2  Ultra-short                     62
# 3  Ultra-short                     36
# 4        Short                    250
#
#                                                Title  Number_of_Citations  \
# 0  Bismark: a flexible aligner and methylation ca...                 1550
# 1        BRAT: bisulfite-treated reads analysis tool                   64
# 2  BRAT-BW: efficient and accurate mapping of bis...                   70
# 3  BS Seeker: precise mapping for bisulfite seque...                  215
# 4  BS-Seeker2: a versatile aligning pipeline for ...                  173
#
#   Indexing  ... Pairwise_alignment_2 Pairwise_alignment (DP-based?)  \
# 0   BWT-FM  ...     Hamming Distance                              N
# 1  Hashing  ...     Hamming Distance                              N
# 2   BWT-FM  ...     Hamming Distance                              N
# 3   BWT-FM  ...     Hamming Distance                              N
# 4   BWT-FM  ...       Local & Global                              Y
#
#   fix length seed Variable length seed (hybrid seeding) spaced seed  \
# 0               Y                                     N           N
# 1               Y                                     N           N
# 2               N                                     Y           N
# 3               Y                                     N           N
# 4               Y                                     N           N
#
#   chain_of_seeds Application        email - first author  \
# 0              N      BS-Seq   felix.krueger@bbsrc.ac.uk
# 1              N      BS-Seq           elenah@cs.ucr.edu
# 2              N      BS-Seq      elenayharris@gmail.com
# 3              N      BS-Seq  paoyang@gate.sinica.edu.tw
# 4              N      BS-Seq       guoweilong@cau.edu.cn
#
#        email - last author Verified
# 0                      NaN      NaN
# 1  stefano.lonardi@ucr.edu      NaN
# 2  stefano.lonardi@ucr.edu      NaN
# 3    matteop@mcdb.ucla.edu      NaN
# 4    matteop@mcdb.ucla.edu      NaN
#
# [5 rows x 24 columns]
